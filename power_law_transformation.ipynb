# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("C:\\Users\\khush\\OneDrive\\Pictures\\Camera Roll\\fog_image.jpeg")


cv2.imshow("Fog Image",img)

cv2.waitKey(0)

cv2.destroyAllWindows()

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.imshow(img_rgb)
plt.axis('off') 
plt.show()

# %%
gamma=2.5

gamma_corrected = np.array(255*(img / 255) ** gamma , dtype = 'uint8') 

plt.imshow(gamma_corrected)
plt.axis('off') 
plt.show()

# %%
gamma=8.5

gamma_corrected2 = np.array(255*(img / 255) ** gamma, dtype = 'uint8') 

plt.imshow(gamma_corrected2)
plt.axis('off') 
plt.show()

# %%
gamma=5.5

gamma_corrected4 = np.array(255*(img / 255) ** gamma, dtype = 'uint8') 

plt.imshow(gamma_corrected4)
plt.axis('off') 
plt.show()

# %%
gamma=5.5

gamma_corrected3 = np.array(img ** gamma, dtype = 'uint8') 

plt.imshow(gamma_corrected3)
plt.axis('off') 
plt.show()

# %%
mse_12 = np.mean((img - gamma_corrected ) ** 2)
mse_13 = np.mean((img - gamma_corrected2) ** 2)
mse_14 = np.mean((img - gamma_corrected4) ** 2)

print(mse_12, mse_13, mse_14)
# Out:
# 96.90610384462941 127.14984145858105 110.41983749504558

# %%
values = [mse_12,  mse_14 ,mse_13]


labels = ['gamma=2.5',  'gamma=5.5', 'gamma=8.5']


plt.plot(labels, values, marker='o', linestyle='-')
plt.xlabel('Values')
plt.ylabel('Data')
plt.title('Plot of Three Values')
plt.grid(True)
plt.show()

# %%
# !pip install opencv
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv
